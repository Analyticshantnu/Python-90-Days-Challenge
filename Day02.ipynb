# %% [markdown]
# Q1. Write a Python program to calculate the length of a string.

# %%
# Input a string from the user
text = input("Enter a string: ")

# Calculate and display the length
length = len(text)

print("The length of the string is:", length)
# Out:
# Enter a string:  shantnu grewal
# The length of the string is: 14

# %% [markdown]
# Q2. Write a Python program to count the number of characters (character frequency) in a string.
# Sample String : google.com'

# %%
string = "google.com"
frequency = {}
for char in string:
    frequency[char] = frequency.get(char, 0) + 1

print(frequency)
# Out:
# {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}

# %% [markdown]
# Q3. Write a Python program to get a string made of the first 2 and last 2 characters of a given string. If the string length is less than 2, return the empty string instead.
# Sample String : 'w3resource'
# Expected Result : 'w3ce'
# Sample String : 'w3'
# Expected Result : 'w3w3'
# Sample String : ' w'
# Expected Result : Empty String

# %%
def first_last_chars(s):
    if len(s) < 2:
        return ""
    return s[:2] + s[-2:]
    
string = "w3resource"
print(first_last_chars(string))
# Out:
# w3ce

# %% [markdown]
# Q4. Write a Python program to get a string from a given string where all occurrences of its first char have been changed to '$', except the first char itself.
# Sample String : 'restart'
# Expected Result : 'resta$t'

# %%
def change_char(s):
    if len(s) == 0:
        return s
    first_char = s[0]
    return first_char +  s[1:].replace(first_char, '$')
string = "restart"
print(change_char(string))
# Out:
# resta$t

# %% [markdown]
# Q5. Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.
# Sample String : 'abc', 'xyz'
# Expected Result : 'xyc abz'

# %%
def swap_first_two(s1, s2):
    new_s1 = s2[:2] + s1[2:]
    new_s2 = s1[:2] + s2[2:]
    return new_s1 + " " + new_s2


print(swap_first_two("abc", "xyz"))
# Out:
# xyc abz

# %% [markdown]
# Q6. Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing', add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.
# Sample String : 'abc'
# Expected Result : 'abcing'
# Sample String : 'string'
# Expected Result : 'stringly'

# %%
def add_ing(s):
    if len(s) < 3:
        return s
    elif s.endswith("ing"):
        return s + "ly"
    else:
        return s + "ing"

print(add_ing("abc"))
print(add_ing("string"))
# Out:
# abcing
# stringly

# %% [markdown]
# Q7. Write a Python program to find the first appearance of the substrings 'not' and 'poor' in a given string. If 'not' follows 'poor', replace the whole 'not'...'poor' substring with 'good'. Return the resulting string.
# Sample String : 'The lyrics is not that poor!'
# 'The lyrics is poor!'

# %%
def replace_not_poor(s):
    not_pos = s.find('not')
    poor_pos = s.find('poor')

    if not_pos < poor_pos and not_pos != -1 and poor_pos != -1:
        s = s[:not_pos] + 'good' + s[poor_pos + 4:]

    return s


print(replace_not_poor('The lyrics is not that poor!'))
print(replace_not_poor('The lyrics is poor!'))
# Out:
# The lyrics is good!
# The lyrics is poor!

# %% [markdown]
# Q8. Write a Python function that takes a list of words and return the longest word and the length of the longest one.
# Sample Output:
# Longest word: Exercises
# Length of the longest word: 9

# %%
def longest_word(words):
    longest = max(words, key=len)
    return longest, len(longest)


words = ["Python", "Exercises", "Programming", "Code"]

word, length = longest_word(words)

print("Longest word:", word)
print("Length of the longest word:", length)
# Out:
# Longest word: Programming
# Length of the longest word: 11

# %% [markdown]
# Q9. Remove nth character from a string.

# %%
def remove_nth_character(string, n):
    return string[:n] + string[n + 1]

string = input("Enter a string: ")
n = int(input("Enter the index to remove: "))
result = remove_nth_character(string , n)
print("String after removing the character:", result)
# Out:
# Enter a string:  python
# Enter the index to remove:  2
# String after removing the character: pyh

# %% [markdown]
# Q10.  Swap first and last chars of a string.

# %%
def swap_first_last(string):
    if len(string) <= 1:
        return string
    return string[-1] + string[1:-1] + string[0]

string = input("Enter a string: ")
result = swap_first_last(string)
print("String after swapping first and last characters:", result)
# Out:
# Enter a string:  python
# String after swapping first and last characters: nythop

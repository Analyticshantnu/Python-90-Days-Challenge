# %% [markdown]
#                                        📘 Day 1: Python Basics - 10 Beginner Problems
#
# Q1.Write a Python program to print:
#
# Hello Python

# %%
print("Hello python")
# Out:
# Hello python

# %% [markdown]
# Q2.Write a Python program to print your:
#
# Name
#
# Course
#
# City
#
# (Use three print() statements.)

# %%
Name = "shantnu grewal"
Course = "Data analyst"
city = "Delhi"

print(Name)
print(Course)
print(city)
# Out:
# shantnu grewal
# Data analyst
# Delhi

# %% [markdown]
# Q3.Write a Python program that prints any two sentences on two different lines.

# %%
print("I am shantnu. \nI am learning Ai skills")
# Out:
# I am shantnu.
# I am learning Ai skills

# %% [markdown]
# Q4.What is a comment in Python? Write one example of a single-line comment and print a message below

# %%
A comment in Python is a line that is not executed by the program.
It is used to explain the code so that it is easy to understand.

# %%
# This is a single-line comment
print("This line will be executed")
# Out:
# This line will be executed

# %% [markdown]
# Q5. Write a Python program to print the result of addition of two numbers.

# %%
num1= int(input("Enter 1st number"))
num2= int(input("Enter 2nd number"))
print(num1+ num2)
# Out:
# Enter 1st number 67
# Enter 2nd number 76
# 143

# %% [markdown]
# Q6. Write a Python program to print your favorite color.

# %%
color= "Red"
print(f"My favorite color is {color}")
# Out:
# My favorite color is Red

# %% [raw]
# Q7. Write a Python program to print the type of a number using type().

# %%
num = 78.019
print(type(num))
# Out:
# <class 'float'>

# %% [raw]
# Q8. Write a Python program to print a message using single quotes.

# %%
a = ('This is shantnu and I am python developer')
print(a)
# Out:
# This is shantnu and I am python developer

# %% [raw]
# Q9. What will be the output of the following code? print(10) print("10")

# %%
print(10)   #This is integer
print("10")  #This is string
# Out:
# 10
# 10

# %% [raw]
# Q10. Fill in the blank to make the program print the message correctly: fruit = "mango"
#
# Fill in the blank below
# print(_______________)

# %%
fruit = "Mango"
print(fruit)
# Out:
# Mango
